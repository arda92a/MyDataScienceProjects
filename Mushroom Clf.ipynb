# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
sns.countplot(data=df,x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl = LabelEncoder()
for i in df.columns:
    df[i]=lbl.fit_transform(df[i])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True,annot_kws={"size": 7})
# Out:
# <Axes: >

# %%
df["veil-type"].unique()
# Out:
# array([0])

# %%
df.drop("veil-type",axis=1,inplace=True)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True,annot_kws={"size": 7},cmap="coolwarm")
# Out:
# <Axes: >

# %%
df_corrWithClass = df.corr().drop("class",axis=0)["class"]

# %%
df_corrWithClass = pd.DataFrame(df_corrWithClass)

# %%
df_corrWithClass.sort_values(by="class",ascending=True)
# Out:
#                              class
# gill-color               -0.530566
# bruises                  -0.501530
# ring-type                -0.411771
# stalk-root               -0.379361
# gill-spacing             -0.348387
# stalk-surface-above-ring -0.334593
# stalk-surface-below-ring -0.298801
# ring-number              -0.214366
# stalk-color-above-ring   -0.154003
# stalk-color-below-ring   -0.146730
# stalk-shape              -0.102019
# odor                     -0.093552
# cap-color                -0.031384
# cap-shape                 0.052951
# gill-attachment           0.129200
# veil-color                0.145142
# spore-print-color         0.171961
# cap-surface               0.178446
# habitat                   0.217179
# population                0.298686
# gill-size                 0.540024

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
y=df["class"].values
X=df.iloc[:,1:23].values
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.3,shuffle=True,stratify=y)

svc=SVC()
svc.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
yhead_svc=svc.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
print("SVC accuracy on test:", accuracy_score(ytest,yhead_svc))
print("SVC accuracy on train:", accuracy_score(ytrain,svc.predict(xtrain)))
# Out:
# SVC accuracy on test: 0.9897456931911403
# SVC accuracy on train: 0.9905029897995076

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression(max_iter=500)
lg.fit(xtrain,ytrain)

yhead_lg=lg.predict(xtest)

print("Logistic regression accuracy on test:", accuracy_score(ytest,yhead_lg))
print("Logistic regression accuracy on train:", accuracy_score(ytrain,lg.predict(xtrain)))
# Out:
# Logistic regression accuracy on test: 0.9536505332239541
# Logistic regression accuracy on train: 0.9512838550826591

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()
clf.fit(xtrain,ytrain)

yhead_rf=clf.predict(xtest)

print("Random forest accuracy on test:", accuracy_score(ytest,yhead_rf))
print("Random forest accuracy on train:", accuracy_score(ytrain,clf.predict(xtrain)))

feature_importances=clf.feature_importances_
feature_name=df.iloc[:,1:23].columns
# Out:
# Random forest accuracy on test: 1.0
# Random forest accuracy on train: 1.0

# %%
feature_importance_df = pd.DataFrame({'Feature': feature_name, 'Importance': feature_importances})

# %%
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df
# Out:
#                      Feature  Importance
# 4                       odor    0.180328
# 7                  gill-size    0.117254
# 8                 gill-color    0.103027
# 18         spore-print-color    0.086503
# 19                population    0.072906
# 17                 ring-type    0.071038
# 10                stalk-root    0.063411
# 3                    bruises    0.057153
# 11  stalk-surface-above-ring    0.042677
# 12  stalk-surface-below-ring    0.037280
# 6               gill-spacing    0.035055
# 20                   habitat    0.031791
# 14    stalk-color-below-ring    0.018930
# 2                  cap-color    0.016250
# 9                stalk-shape    0.016194
# 16               ring-number    0.015673
# 13    stalk-color-above-ring    0.014107
# 1                cap-surface    0.010012
# 0                  cap-shape    0.004234
# 15                veil-color    0.003923
# 5            gill-attachment    0.002256
